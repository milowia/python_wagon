# %% [markdown]
# <a href="https://colab.research.google.com/github/milowia/python_wagon/blob/main/1_Recall_DataFrame_Basics_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ![Emil](data:image/png;base64,...)

# %% [markdown]
# # Recall DataFrame Basics

# %% [markdown]
# Execute the following cell

# %%
import pandas as pd

df = pd.DataFrame({"A": [1, 2, 3, 4, 5, 6],
                   "B": [7, 8, 9, 10, 11, 12],
                   "C": [13, 14, 15, 16, 17, 18],
                   "D": ["a", "a", "a", "b", "b", "b"],
                   "E": ["c", "d", "c", "d", "c", "d"]})

# %% [markdown]
# ## DataFrame attributes

# %% [markdown]
# Display `df` columns and index names

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.index.values
# Out:
# array([0, 1, 2, 3, 4, 5])

# %% [markdown]
# ## Play with DataFrame columns

# %% [markdown]
# Put column B in a variable `df_B`. What is the type of this variable?

# %%
df_B = df["B"]

type(df_B)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Does the following code change anything? Why?
#
#
# `df_B = df[["B"]]`

# %%
df[["B"]]
# Out:
#     B
# 0   7
# 1   8
# 2   9
# 3  10
# 4  11
# 5  12

# %% [markdown]
# Create a column F filled with 12

# %%
df['F']=12

# %% [markdown]
# Create a DataFrame `df_E_B` containing columns B and E. We want column E to be **before** column B.

# %%
df_E_B=df[["E", "B"]]

df_E_B
# Out:
#    E   B
# 0  c   7
# 1  d   8
# 2  c   9
# 3  d  10
# 4  c  11
# 5  d  12

# %% [markdown]
# ## Filter a DataFrame

# %% [markdown]
# Display rows 1 to 3 and columns B, C, D from `df` DataFrame.

# %%
df.loc[1:3, ['B', 'C', 'D']]
# Out:
#     B   C  D
# 1   8  14  a
# 2   9  15  a
# 3  10  16  b

# %% [markdown]
# Why does this line of code cause an error?

# %%
df.iloc[1:3, ["B", "C", "D"]]

# %% [markdown]
# df.iloc only accept integer position-based indexing

# %% [markdown]
# ## Boolean Indexing

# %% [markdown]
# Select rows from `df` where the value in column B is greater than or equal to 8.

# %%
mask_B8 = (df['B'] >= 8)
df_B8 = df[mask_B8]
df_B8
# Out:
#    A   B   C  D  E   F
# 1  2   8  14  a  d  12
# 2  3   9  15  a  c  12
# 3  4  10  16  b  d  12
# 4  5  11  17  b  c  12
# 5  6  12  18  b  d  12

# %% [markdown]
# Select rows from df where the value in column B is greater than or equal to 8 and the value in column D is equal to "a".

# %%
mask_B8_Da = (df['B'] >= 8) & (df['D']=='a')
df_B8_Da = df[mask_B8_Da]
df_B8_Da
# Out:
#    A  B   C  D  E   F
# 1  2  8  14  a  d  12
# 2  3  9  15  a  c  12

# %% [markdown]
# What does this line of code do?
# change the value of row ["E"]=="c", cloumn "A" to 8

# %%
df.loc[df["E"]=="c", "A"] = 8

# %%
df
# Out:
#    A   B   C  D  E   F
# 0  8   7  13  a  c  12
# 1  2   8  14  a  d  12
# 2  8   9  15  a  c  12
# 3  4  10  16  b  d  12
# 4  8  11  17  b  c  12
# 5  6  12  18  b  d  12

# %% [markdown]
# ## Operations on DataFrame columns

# %% [markdown]
# Calculate the average of columns A, B and F **by using the pd.DataFrame() [inbuilt function](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mean.html).**

# %%
df['A'].mean()
# Out:
# 6.0

# %% [markdown]
# What happens if we repeat the previous instruction but pass **axis=1** as parameter to `.mean()`function?

# %%
df['A'].mean(axis=1)
# Out:
# 6.0
